# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv()
#
# NameError: name 'pd' is not defined

# %%
df
# Out:
#     <!doctype html><html lang="en-US" dir="ltr"><head><base href="https://accounts.google.com/v3/signin/"><meta name="referrer" content="origin"><style data-href="https://www.gstatic.com/_/mss/boq-identity/_/ss/k=boq-identity.AccountsSignInUi.3PkWJ8J_UA8.L.X.O/am=DggrInFsAAr_B0ABAAGAAgUAAAAAAAAAQKCBWEI/d=1/ed=1/rs=AOaEmlHUK0o0kKlz9FtxvImAKwJhAEXsjw/m=identifierview  \
# 0                                             --c-brsz
# 1      )}.bEbGY{-webkit-box-pack:center;-webkit-jus...
# 2                                             --c-brsz
# 3      )}.no7ij{display:-webkit-box;display:-webkit...
# 4                                             --c-brsz
# ..                                                 ...
# 275                                              g:"1"
# 276                                              i:!0}
# 277  X.prototype.j=function(){var b=this.h.querySel...
# 278        &apos;);h.B&&(f=f.replace(/(^|[\r\n\t ]) /g
# 279                       </script></div></div></body>
# ...
